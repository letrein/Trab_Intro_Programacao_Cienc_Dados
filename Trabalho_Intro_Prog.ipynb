# %% [markdown]
# # Dados da Policia Civil

# %% [markdown]
# ### Importando pandas, lendo base de dados original e buscando valores nulos

# %%
import pandas as pd
df_cru = pd.read_csv('../PÓS/2024-04-01_sigesguarda_-_Base_de_Dados.csv',sep = ";", encoding='latin-1')

# %% [markdown]
# ## Avaliando dados inicialmente

# %%
df_cru.head(25)
# Out:
#    ATENDIMENTO_ANO,ATENDIMENTO_BAIRRO_NOME,FLAG_FLAGRANTE,LOGRADOURO_NOME,NATUREZA1_DESCRICAO,OCORRENCIA_HORA,OCORRENCIA_MES,ORIGEM_CHAMADO_DESCRICAO,REGIONAL_FATO_NOME,SECRETARIA_NOME,SECRETARIA_SIGLA,SERVICO_NOME
# 0   2009,FAZENDINHA,NÃO, CARLOS KLEMTZ,Roubo,1900...
# 1   2009,UBERABA,NÃO,DOUTOR JOÃO DE PAULA MOURA ...
# 2   2009,SÃTIO CERCADO,NÃO,EDGARD CAVALCANTI DE ...
# 3   2009,SANTA CÃNDIDA,NÃO, NOVA DE COLOMBO,TrÃ¢...
# 4   2009,CENTRO,SIM,PRESIDENTE FARIA,Roubo,1900-01...
# 5   2009,BOA VISTA,NÃO,SANTA EDWIGES,InvasÃ£o,190...
# 6   2009,TABOÃO,NÃO, OSWALDO MACIEL,Apoio,1900-0...
# 7   2009,CENTRO,NÃO,TOBIAS DE MACEDO,Fundada susp...
# 8   2009,CENTRO,NÃO,TIRADENTES,SubstÃ¢ncia ilÃ­ci...
# 9   2009,CENTRO,NÃO,TOBIAS DE MACEDO,Atitude susp...
# 10  2009,CIDADE INDUSTRIAL,NÃO, JOSÃ TISSI,Invas...
# 11  2009,BOQUEIRÃO,NÃO, MARECHAL FLORIANO PEIXOT...
# 12  2009,BATEL,NÃO,SILVA JARDIM,Queda de Ã¡rvore,...
# 13  2009,BATEL,NÃO,SILVA JARDIM,Alagamento,1900-0...
# 14  2009,FAZENDINHA,NÃO,DANIEL PETERSEN,Queda de ...
# 15  2009,CIDADE INDUSTRIAL,NÃO,SETEMBRINO PORTELL...
# 16  2009,ALTO BOQUEIRÃO,NÃO,EXPEDICIONÃRIO ESTA...
# 17  2009,CAPÃO RASO,NÃO,PINHEIRINHO,Roubo,1900-0...
# 18  2009,NOVO MUNDO,NÃO, THEOPHILO MANSUR,Dano,19...
# 19  2009,CIDADE INDUSTRIAL,NÃO,ESTANISLAU KUCEK,V...
# 20  2009,NOVO MUNDO,NÃO,ROSA CARVALHO CHAVES,Anim...
# 21  2009,UBERABA,NÃO,DOUTOR ALFREDO VIEIRA BARCEL...
# 22  2009,PORTÃO,NÃO, REPÃBLICA ARGENTINA,Atitud...
# 23  2009,CENTRO,NÃO, RUI BARBOSA,Atitude suspeita...
# 24  2009,ORLEANS,NÃO,CANAL BELÃM,DesinteligÃªnci...

# %% [markdown]
# # Limpeza de dados

# %% [markdown]
# ### Busca por valores nulos

# %%
df_cru.isnull().sum()
# Out:
# ATENDIMENTO_ANO,ATENDIMENTO_BAIRRO_NOME,FLAG_FLAGRANTE,LOGRADOURO_NOME,NATUREZA1_DESCRICAO,OCORRENCIA_HORA,OCORRENCIA_MES,ORIGEM_CHAMADO_DESCRICAO,REGIONAL_FATO_NOME,SECRETARIA_NOME,SECRETARIA_SIGLA,SERVICO_NOME    0
# dtype: int64

# %% [markdown]
# ## Fazendo novo dataset

# %% [markdown]
# #### Selecionando as colunas de interesse, sendo estas com menor quantidade de valores nulos

# %%
colunas_interesse = ['ATENDIMENTO_ANO', 'ATENDIMENTO_BAIRRO_NOME', 'FLAG_FLAGRANTE', 'LOGRADOURO_NOME','NATUREZA1_DESCRICAO','OCORRENCIA_HORA','OCORRENCIA_MES','ORIGEM_CHAMADO_DESCRICAO','REGIONAL_FATO_NOME','SECRETARIA_NOME','SECRETARIA_SIGLA', 'SERVICO_NOME']
df = df_cru[colunas_interesse]
df.to_csv('../PÓS/df_policiacivil_adaptado.csv', index=False)  
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 colunas_interesse = ['ATENDIMENTO_ANO', 'ATENDIMENTO_BAIRRO_NOME', 'FLAG_FLAGRANTE', 'LOGRADOURO_NOME','NATUREZA1_DESCRICAO','OCORRENCIA_HORA','OCORRENCIA_MES','ORIGEM_CHAMADO_DESCRICAO','REGIONAL_FATO_NOME','SECRETARIA_NOME','SECRETARIA_SIGLA', 'SERVICO_NOME']
# ----> 2 df = df_cru[colunas_interesse]
#       3 df.to_csv('../PÓS/df_policiacivil_adaptado.csv', index=False)
#       4 df
#
# File c:\Users\chii\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\chii\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\chii\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['ATENDIMENTO_ANO', 'ATENDIMENTO_BAIRRO_NOME', 'FLAG_FLAGRANTE',\n       'LOGRADOURO_NOME', 'NATUREZA1_DESCRICAO', 'OCORRENCIA_HORA',\n       'OCORRENCIA_MES', 'ORIGEM_CHAMADO_DESCRICAO', 'REGIONAL_FATO_NOME',\n       'SECRETARIA_NOME', 'SECRETARIA_SIGLA', 'SERVICO_NOME'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# #### Reavaliação de valores nulos

# %%
df= pd.read_csv('../PÓS/df_policiacivil_adaptado.csv')
df
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_2948\3466214525.py:1: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('../PÓS/df_policiacivil_adaptado.csv')
#         ATENDIMENTO_ANO  ATENDIMENTO_BAIRRO_NOME  FLAG_FLAGRANTE  \
# 0       ---------------  -----------------------  --------------
# 1                  2009        CIDADE INDUSTRIAL             NÃO
# 2                  2009               FAZENDINHA             NÃO
# 3                  2009                  UBERABA             NÃO
# 4                  2009            SÍTIO CERCADO             NÃO
# ...                 ...                      ...             ...
# 429342             2022                   PORTÃO             NÃO
# 429343             2022            SÍTIO CERCADO             NÃO
# 429344             2022          JARDIM BOTÂNICO             NÃO
# 429345             2022          JARDIM BOTÂNICO             NÃO
# 429346             2022                    XAXIM             NÃO
#
#                                           LOGRADOURO_NOME  \
# 0       ----------------------------------------------...
# 1                                    DAVI XAVIER DA SILVA
# 2                                           CARLOS KLEMTZ
# 3                        DOUTOR JOÃO DE PAULA MOURA BRITO
# 4                        EDGARD CAVALCANTI DE ALBUQUERQUE
# ...                                                   ...
# 429342                                REPÚBLICA ARGENTINA
# 429343                          RICARDO GASPARIAN MACHADO
# 429344                                   SETE DE SETEMBRO
# 429345                                   SETE DE SETEMBRO
# 429346                                             BR-476
#
#                                       NATUREZA1_DESCRICAO  OCORRENCIA_HORA  \
# 0       ----------------------------------------------...  ---------------
# 1                                                 Alarmes         15:14:00
# 2                                                   Roubo         15:22:00
# 3                                                 Animais         15:59:00
# 4                                                 Animais         16:13:00
# ...                                                   ...              ...
# 429342                                             Ameaça         06:09:00
# 429343                                              Roubo         06:26:00
# 429344                                              Apoio         06:28:00
# 429345  Avaria em Equipamento/Patrimônio (não intencio...         06:35:00
# 429346                                Importunação sexual         07:21:00
#
#         OCORRENCIA_MES                           ORIGEM_CHAMADO_DESCRICAO  \
# 0       --------------  ----------------------------------------------...
# 1                    1                                                  .
# 2                    1                                                153
# 3                    1                                                156
# 4                    1                                                156
# ...                ...                                                ...
# 429342              12                                                153
# 429343              12                                                153
# 429344              12                                                153
# 429345              12                                           IMEDIATA
# 429346              12                                                153
#
#           REGIONAL_FATO_NOME  \
# 0       --------------------
# 1                        CIC
# 2                     PORTÃO
# 3                     CAJURU
# 4                BAIRRO NOVO
# ...                      ...
# 429342                PORTÃO
# 429343           BAIRRO NOVO
# 429344                MATRIZ
# 429345                MATRIZ
# 429346             BOQUEIRÃO
#
#                                           SECRETARIA_NOME  SECRETARIA_SIGLA  \
# 0       ----------------------------------------------...  ----------------
# 1                                 FUNDAÇÃO DE AÇÃO SOCIAL               FAS
# 2                      SECRETARIA MUNICIPAL MEIO AMBIENTE              SMMA
# 3                           SECRETARIA MUNICIPAL DA SAÚDE               SMS
# 4                           SECRETARIA MUNICIPAL DA SAÚDE               SMS
# ...                                                   ...               ...
# 429342   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO              SMDT
# 429343                            URBANIZAÇÃO DE CURITIBA              URBS
# 429344   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO              SMDT
# 429345   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO              SMDT
# 429346   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO              SMDT
#
#                                              SERVICO_NOME
# 0       ----------------------------------------------...
# 1                                                    SIGA
# 2                                                  NORMAL
# 3                                                   SACAF
# 4                                                   SACAF
# ...                                                   ...
# 429342                                             NORMAL
# 429343                                             NORMAL
# 429344                                             NORMAL
# 429345                                               GPEO
# 429346                                             NORMAL
#
# [429347 rows x 12 columns]

# %%
#verificando presença de valores nulos
df.isnull().sum()
# Out:
# ATENDIMENTO_ANO              19
# ATENDIMENTO_BAIRRO_NOME     145
# FLAG_FLAGRANTE                0
# LOGRADOURO_NOME               0
# NATUREZA1_DESCRICAO           0
# OCORRENCIA_HORA               0
# OCORRENCIA_MES                0
# ORIGEM_CHAMADO_DESCRICAO      0
# REGIONAL_FATO_NOME           11
# SECRETARIA_NOME               0
# SECRETARIA_SIGLA              0
# SERVICO_NOME                  0
# dtype: int64

# %% [markdown]
# #### Retirada dos Valores nulos

# %%
df = df.dropna()

# %% [markdown]
#  #### Avaliação de valores nulos e Dtype das colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 429183 entries, 0 to 429346
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ATENDIMENTO_ANO           429183 non-null  object
#  1   ATENDIMENTO_BAIRRO_NOME   429183 non-null  object
#  2   FLAG_FLAGRANTE            429183 non-null  object
#  3   LOGRADOURO_NOME           429183 non-null  object
#  4   NATUREZA1_DESCRICAO       429183 non-null  object
#  5   OCORRENCIA_HORA           429183 non-null  object
#  6   OCORRENCIA_MES            429183 non-null  object
#  7   ORIGEM_CHAMADO_DESCRICAO  429183 non-null  object
#  8   REGIONAL_FATO_NOME        429183 non-null  object
#  9   SECRETARIA_NOME           429183 non-null  object
#  10  SECRETARIA_SIGLA          429183 non-null  object
#  11  SERVICO_NOME              429183 non-null  object
# dtypes: object(12)
# memory usage: 42.6+ MB

# %% [markdown]
# ### Adequação dos dtype das colunas de valor numérico

# %%
#Ajuste das variáveis de ano
df = df[df['ATENDIMENTO_ANO'].apply(lambda x: str(x).isdigit())]
df['ATENDIMENTO_ANO'] = df['ATENDIMENTO_ANO'].astype(int)

#Ajuste das variáveis de mês
df = df[df['OCORRENCIA_MES'].apply(lambda x: str(x).isdigit())]
df['OCORRENCIA_MES'] = df['OCORRENCIA_MES'].astype(int)

#Ajuste das variáveis de hora
df['OCORRENCIA_HORA'] = pd.to_datetime(df['OCORRENCIA_HORA'], format='%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 314575 entries, 1 to 429346
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ATENDIMENTO_ANO           314575 non-null  int32
#  1   ATENDIMENTO_BAIRRO_NOME   314575 non-null  object
#  2   FLAG_FLAGRANTE            314575 non-null  object
#  3   LOGRADOURO_NOME           314575 non-null  object
#  4   NATUREZA1_DESCRICAO       314575 non-null  object
#  5   OCORRENCIA_HORA           314575 non-null  datetime64[ns]
#  6   OCORRENCIA_MES            314575 non-null  int32
#  7   ORIGEM_CHAMADO_DESCRICAO  314575 non-null  object
#  8   REGIONAL_FATO_NOME        314575 non-null  object
#  9   SECRETARIA_NOME           314575 non-null  object
#  10  SECRETARIA_SIGLA          314575 non-null  object
#  11  SERVICO_NOME              314575 non-null  object
# dtypes: datetime64[ns](1), int32(2), object(9)
# memory usage: 28.8+ MB

# %% [markdown]
# ## Avaliação individual das colunas

# %% [markdown]
# #### Foi colocado individualmente todas as colunas em busca de valores que não fizessem sentido para a análise. Segue os principais problemas encontrados e adequações realizadas

# %% [markdown]
# ### Avaliação dos Bairros

# %%
df['ATENDIMENTO_BAIRRO_NOME'].unique()
# Out:
# array(['CIDADE INDUSTRIAL', 'FAZENDINHA', 'UBERABA', 'SÍTIO CERCADO',
#        'TATUQUARA', 'SANTA CÂNDIDA', 'BOQUEIRÃO', 'CENTRO', 'BOA VISTA',
#        'TABOÃO', 'XAXIM', 'PILARZINHO', 'REBOUÇAS', 'ÁGUA VERDE', 'BATEL',
#        'NOVO MUNDO', 'ALTO BOQUEIRÃO', 'CAPÃO RASO', 'JARDIM BOTÂNICO',
#        'PORTÃO', 'ORLEANS', 'SANTA FELICIDADE', 'CASCATINHA',
#        'CAPÃO DA IMBUIA', 'BARREIRINHA', 'SEMINÁRIO', 'CAMPO COMPRIDO',
#        'PRADO VELHO', 'PINHEIRINHO', 'BUTIATUVINHA',
#        'CAMPINA DO SIQUEIRA', 'CAJURU', 'SÃO FRANCISCO', 'CENTRO CÍVICO',
#        'SÃO BRAZ', 'UMBARÁ', 'CAXIMBA', 'JARDIM SOCIAL', 'BACACHERI',
#        'CAMPO DE SANTANA', 'SANTO INÁCIO', 'JARDIM DAS AMÉRICAS',
#        'LINDÓIA', 'GANCHINHO', 'PAROLIN', 'ABRANCHES', 'SÃO JOÃO',
#        'ATUBA', 'TARUMÃ', 'ALTO DA RUA XV', 'MOSSUNGUÊ', 'TINGUI',
#        'BIGORRILHO', 'BAIRRO ALTO', 'HAUER', 'VILA IZABEL', 'CABRAL',
#        'BOM RETIRO', 'GUAÍRA', 'CACHOEIRA', 'AUGUSTA', 'CRISTO REI',
#        'AHÚ', 'ALTO DA GLÓRIA', 'GUABIROTUBA', 'MERCÊS', 'SANTA QUITÉRIA',
#        'SÃO MIGUEL', 'SÃO LOURENÇO', 'FANNY', 'JUVEVÊ', 'VISTA ALEGRE',
#        'HUGO LANGE', 'RIVIERA', 'LAMENHA PEQUENA', 'INDICAÇÕES CANCELADA',
#        'BAIRRO NAO INFORMADO', 'BAIRRO FICTÍCIO', 'CIDADE JARDIM',
#        'VENEZA', 'PLANTA MEIRELES', 'TANGUA', 'MONTE REY', 'JD EUROPA',
#        'BORDA DO CAMPO', 'JARDIM BOA VISTA', 'VILA PERNETA ', 'SEM DADOS',
#        'CAMPO DE SÃO BENEDIT', 'QUATRO BARRAS', 'LOT. MARINONI',
#        'SÃO JORGE', 'BAIRRO NÃO LOCALIZAD', 'BRAGA', 'JARDIM LOANDA',
#        'NÃO INFORMADO ', 'SANTA TEREZINHA', 'SANTA TERESINHA',
#        'JARDIM WEISSOPOLIS', 'SITIO DAS PALMEIRAS', 'CAMPO PEQUENO ',
#        'NI', 'THOMAS COELHO', 'NF', 'SÃO THOMAS', 'JARDIM INDUSTRIAL',
#        'ROÇA NEGRA', 'SÃO THOMAZ', 'PINHAIS', 'GRALHA AZUL', 'MARACANÃ',
#        'VILA BANCÁRIA', 'JARDIM BOM PASTOR', 'SAO GERONIMO', 'RIO VERDE',
#        'JD IPE', 'IGUAÇÚ 1', 'AGUAS BELAS', 'ÁGUAS BELAS', 'IGUAÇU 01',
#        'ESTADOS', 'CIC', 'JR TAISA', 'PLANTA DEODORO', 'MAUA',
#        'COLONIA FARIA', 'NAÇÕES', 'JARDIM SANTA MÔNICA',
#        'LOTEAMENTO SÃO GERÔN', 'CAMPO PEQUENO', 'TAMANDARE ',
#        'CAMPO LARGO', 'BOQUEIRÃO ', 'JARDIM BELA VISTA',
#        'ESTANCIA PINHAIS ', 'COLONIA SAO VENANCIO', 'FRANCISCO GORSKI',
#        'OSASCO', 'PARQUE DAS FONTES', 'PINEVILLE', 'FERRARIA',
#        'BORDA DO CAMPO ', ' JARDIM OSASCO', 'JARDIM PRIMAVERA',
#        'JD DONA BELIZARIA', 'PIRAQUARA', 'JARDIM RAFAELA', 'BARRO PRETO',
#        'BELAS AGUAS', 'EUCALIPTOS', 'VILA GRAZIELA',
#        'CIDADE INDUSTRIAL DE', 'AFONSO PENA', 'PALMEIRINHA', 'IPE 2',
#        'SANTA MONICA', 'GUATUPE', 'SANTO ANTONIO', 'AFONSO PENA ',
#        'SAO SEBASTIAO', 'MAUÁ', 'SÃO GERONIMO', 'OURO FINO',
#        'SANTO ANTÔNIO', 'CAMPINHA GRANDE DO S', ' JARDIM PEDRO DEMETE',
#        'ROÇA GRANDE', 'TINDIQUERA', 'SÃO BENEDITO', 'VILA IPANEMA'],
#       dtype=object)

# %% [markdown]
# ####  Sendo encontrado valores inválidos para os bairros (NI, NF, Cajuru), foram adequados deixando todos os dados em maíusculo e  pela retirada dos valores (NI e NF)

# %%
# Deixando todos em maíusculo
df['REGIONAL_FATO_NOME'] = df['REGIONAL_FATO_NOME'].str.upper()

# Remover as linhas com "NF" na coluna "ATENDIMENTO_BAIRRO_NOME"
df = df[df['ATENDIMENTO_BAIRRO_NOME'] != "NF"]

# Remover as linhas com "NI" na coluna "ATENDIMENTO_BAIRRO_NOME"
df = df[df['ATENDIMENTO_BAIRRO_NOME'] != "NI"]

# %% [markdown]
# ### Avaliação Logradouros

# %%
df['LOGRADOURO_NOME'].unique()
# Out:
# array(['DAVI XAVIER DA SILVA', ' CARLOS KLEMTZ',
#        'DOUTOR JOÃO DE PAULA MOURA BRITO', ...,
#        'RuaProfessorLoureiroFernandes', 'JOÃO MASSUCHETTO',
#        'General  Teodorico Guimarães'], dtype=object)

# %% [markdown]
# #### Pela dificuldade de visualização, será buscado de forma diferente, através da seleção de colunas que contém "NI" ou "NF"

# %%
df[df['LOGRADOURO_NOME'] == "NI"]
# Out:
#         ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME FLAG_FLAGRANTE  \
# 6837               2009                  CAJURU            NÃO
# 25334              2010               TATUQUARA            SIM
# 53322              2011               TATUQUARA            NÃO
# 56042              2011               TATUQUARA            NÃO
# 76644              2012       CIDADE INDUSTRIAL            NÃO
# 201636             2017        CAMPO DE SANTANA            NÃO
# 201640             2017                  CENTRO            NÃO
# 216258             2018        SANTA FELICIDADE            NÃO
# 250506             2019             PINHEIRINHO            NÃO
#
#        LOGRADOURO_NOME  NATUREZA1_DESCRICAO     OCORRENCIA_HORA  \
# 6837                NI  Retirada de invasão 1900-01-01 09:30:00
# 25334               NI                 Dano 1900-01-01 22:10:00
# 53322               NI                 Dano 1900-01-01 16:12:00
# 56042               NI   Substância Ilícita 1900-01-01 14:14:00
# 76644               NI                 Dano 1900-01-01 10:06:00
# 201636              NI                 Dano 1900-01-01 11:41:00
# 201640              NI            Tentativa 1900-01-01 12:25:00
# 216258              NI                Apoio 1900-01-01 15:40:00
# 250506              NI                 Dano 1900-01-01 14:20:00
#
#         OCORRENCIA_MES ORIGEM_CHAMADO_DESCRICAO REGIONAL_FATO_NOME  \
# 6837                 4                     FONE             CAJURU
# 25334                1                      153        PINHEIRINHO
# 53322                3                      153        PINHEIRINHO
# 56042                5                      153        PINHEIRINHO
# 76644                5                      153                CIC
# 201636               9                       G5          TATUQUARA
# 201640               9                 IMEDIATA             MATRIZ
# 216258               5                     FONE   SANTA FELICIDADE
# 250506               8                      153        PINHEIRINHO
#
#                                           SECRETARIA_NOME SECRETARIA_SIGLA  \
# 6837                   COMPANHIA DE HABITAÇÃO DE CURITIBA            COHAB
# 25334                    SECRETARIA MUNICIPAL DA EDUCAÇÃO              SME
# 53322                    SECRETARIA MUNICIPAL DA EDUCAÇÃO              SME
# 56042                    SECRETARIA MUNICIPAL DA EDUCAÇÃO              SME
# 76644   SECRETARIA MUNICIPAL DO ESPORTE, LAZER E JUVEN...            SMELJ
# 201636                   SECRETARIA MUNICIPAL DA EDUCAÇÃO              SME
# 201640   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO             SMDT
# 216258                            FUNDAÇÃO DE AÇÃO SOCIAL              FAS
# 250506   SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO             SMDT
#
#        SERVICO_NOME
# 6837         NORMAL
# 25334        NORMAL
# 53322        NORMAL
# 56042        NORMAL
# 76644        NORMAL
# 201636       NORMAL
# 201640  GTM (Motos)
# 216258       NORMAL
# 250506       NORMAL

# %%
df[df['LOGRADOURO_NOME'] == "NF"]
# Out:
# Empty DataFrame
# Columns: [ATENDIMENTO_ANO, ATENDIMENTO_BAIRRO_NOME, FLAG_FLAGRANTE, LOGRADOURO_NOME, NATUREZA1_DESCRICAO, OCORRENCIA_HORA, OCORRENCIA_MES, ORIGEM_CHAMADO_DESCRICAO, REGIONAL_FATO_NOME, SECRETARIA_NOME, SECRETARIA_SIGLA, SERVICO_NOME]
# Index: []

# %% [markdown]
# #### Adequando variáveis

# %%
# Deixando todos em maíusculo
df['LOGRADOURO_NOME'] = df['LOGRADOURO_NOME'].str.upper()

# Remover a linha com "NI" na coluna "LOGRADOURO_NOME"
df = df[df['LOGRADOURO_NOME'] != "NI"]

# %% [markdown]
# ### Avaliação Origem do chamado

# %%
df['ORIGEM_CHAMADO_DESCRICAO'].unique()
# Out:
# array(['.', '153', '156', 'IMEDIATA', 'CCO URBS', 'CIOSP (190)',
#        'VAZIO "NÃO CADASTRAR" ANTIGO AOS GMS', 'À VIATURA', '199', 'G5',
#        'CCO BARIGUI', 'FONE', 'CCO RUAS DA CIDADANIA', 'OFÍCIO',
#        'AOS GMS', 'SAMU', 'SIGA', 'CCO PUC', 'EMAIL', 'CCO SÍTIO CERCADO',
#        'CCO MUNICIPAL URBS', 'REDE SOCIAL', 'TOTEM RUA SÃO FRANSICO',
#        'CASA DA MULHER BRASILEIRA', 'CENTRAL DE FLAGRANTES', 'NRGM',
#        'VEPPER', 'SETRAN', 'CCO MURALHA DIGITAL',
#        'BOTÃO DO PÂNICO ESCOLAS',
#        'BOTÃO DO PÂNICO PATRULHA MARIA DA PENHA',
#        'ATENDIMENTO E ACOMPANHAMENTO DA PATRULHA MARIA DA PENHA'],
#       dtype=object)

# %% [markdown]
# #### Retirada de valores inválidos

# %%
df = df[df['ORIGEM_CHAMADO_DESCRICAO'] != "."]

# %% [markdown]
# ### Avaliação Tipos de ocorrência

# %%
df['NATUREZA1_DESCRICAO'].unique()
# Out:
# array(['Roubo', 'Animais', 'Trânsito', 'Invasão', 'Apoio',
#        'Fundada Suspeita (Abordagem)', 'Substância Ilícita',
#        'Atitude Suspeita', 'Queda de árvore', 'Alagamento', 'Dano',
#        'Veículo', 'Desinteligência', 'Rixa', 'Averiguação',
#        'Uso indevido do cartão transporte', 'Orientação', 'Furto',
#        'Desabamento', 'Risco de acidente/à vida (Defesa Civil)',
#        'Bueiro entupido', 'Perturbação do sossego', 'Erosão', 'Ameaça',
#        'Alarmes', 'Risco de desabamento / desmoronamento',
#        'Agressão física/verbal', 'Pesca em local proibido', 'Desacato',
#        'Vias de fato', 'Porte Ilegal', 'Risco de acidente / à vida',
#        'Depósito irregular', 'Ataque de insetos',
#        'Proteção ao patrimônio', 'Destelhamento', 'Extorsão',
#        'Queima a céu aberto',
#        'Escrito ou objeto obsceno (panfletos pornográficos)',
#        'Disparo de arma', 'Achado', 'Substância Lícita',
#        'Atos obscenos/libidinosos', 'Incêndio', 'Escolta',
#        'Lesão Corporal', 'Encaminhamento', 'Tentativa', 'Desaparecimento',
#        'Banho em local impróprio',
#        'Fornecimento de bebida alcoólica à menores',
#        'Conduta inconveniente', 'Poluição visual/ambiental',
#        'Criança perdida/desaparecida',
#        'Risco de queda de fios de energia', 'Óbito',
#        'Bueiro aberto/sem tampa', 'Embriaguez', 'Vadiagem', 'Ronda',
#        'Abandono de incapaz', 'Peculato', 'Maus tratos à pessoas',
#        'Situação de risco', 'Suicídio', 'Apologia de crime ou criminoso',
#        'Favorecimento da prostituição', 'Paciente/usuário alterado',
#        'Corte irregular de árvore', 'Vistoria', 'Fuga de aluno/interno',
#        'Explosão', 'Manifestação', 'Risco de queda de galho',
#        'Averiguação (Defesa Civil)', 'Queda de poste', 'Crime ambiental',
#        'Vazamento ou derramamento de Produto Perigoso ou Infectante',
#        'Importunação\xa0sexual', 'Calote', 'Moeda Falsa',
#        'Obstrução de via', 'Retirada de invasão', 'Comércio ambulante',
#        'AIFU', 'Jogo de Azar', 'Abuso de incapazes', 'Infiltração',
#        'Fiscalizações e Orientações', 'Atentado violento ao pudor',
#        'Construção Irregular', 'Homicídio', 'Saturação', 'Prostituição',
#        'Desobediência', 'Denúncia de bomba', 'Afogamento',
#        'Importunação ofensiva ao pudor', 'Menor gazeando aula',
#        'Devolução de coisa achada', 'Estupro', 'Estelionato',
#        'Falsidade ideológica (Falsa Identidade)',
#        'Constrangimento ilegal', 'Calúnia', 'Queda de fios de energia',
#        'Queda de galho', 'Pragas Animais',
#        'Avaria em Equipamento/Patrimônio (não intencional)',
#        'Porte de artefato explosivo', 'Injúria', 'Verificação',
#        'Seqüestro e cárcere privado', 'Aliciamento de menor',
#        'Quedas de objetos ou partes de construções', 'Risco de explosão',
#        'Extravio, sonegação ou inutilização de livro ou doc.', 'Arrastão',
#        'Queda de aeronave', 'Aterro irregular', 'Deslizamenton de Terra',
#        'Apropriação indébita', 'Risco de queda de árvore',
#        'Contrabando ou descaminho',
#        'Usar de uniforme, ou distintivo de função pública que não exerce',
#        'Violação de sepultura/túmulo',
#        'Mendigar, por ociosidade ou cupidez', 'Órgãos acionados',
#        'Menores abordando transeuntes',
#        'Impedimento ou perturbação de cerimônia funerária',
#        'Exploração de menores', 'Material abandonado',
#        'Risco de queda de poste', 'Envenenamento', 'Charlatanismo',
#        'Receptação',
#        'Roubo, furto, extravio, recuperação, apreensão de armas de fogo.',
#        'Uso indevido do telefone público', 'Corrupção ativa',
#        'Resistência', 'Corrupção de menores', 'Concussão',
#        'Violência arbitrária', 'Enxurrada', 'Inundação/Enchente',
#        'Racismo', 'Câmeras de videomonitoramento', 'Sedução', 'Difamação',
#        'Abandono de função', 'Fingir-se funcionário público',
#        'Venda proibida de produtos específicos à menores', 'Rufianismo',
#        'Antecedentes Criminais - Verificação', 'Vilipêndio a cadáver',
#        'Violação de Medida Protetiva Lei Maria da Penha', 'Discriminação',
#        'Homofobia', 'Omissão de socorro', 'Fornecimento de Lona',
#        'Acidente Viatura', 'Falsificação de documento Publico',
#        'Quadrilha ou bando',
#        'Liberação de pessoa presa/apreendida por recusa no recebimento pela DP',
#        'Fuga de paciente', 'Maus tratos a animais', 'Trote Telefonico',
#        'ZELADORIA URBANA', 'Descumprimento lei 15799/2021 COVID-19',
#        'RECUSAR SE IDENTIFICAR AO POLICIAL', 'Câmera Off-Line',
#        'Perseguição (stalking)', 'Incitação ao crime', 'Ataque cão feroz',
#        'Denuncia Improcedente', 'Extravio de Equipamento',
#        'Averiguação (COSEDI)', 'Incendio/Explosão em edificação',
#        'Queda de Revestimento de Fachadas',
#        'Desabamento de Telhado/Cobertura', 'Queda de Muro',
#        'Prevaricação', 'Patrulha Maria da Penha',
#        'Obstrução da Atividade Policial', 'Afundamento de Piso'],
#       dtype=object)

# %% [markdown]
# #### Adequando para apenas primeira letra em maísculo

# %%
df['NATUREZA1_DESCRICAO'] = df['NATUREZA1_DESCRICAO'].str.capitalize()

# %% [markdown]
# ### Avaliação demais colunas

# %%
df['SECRETARIA_NOME'].unique()
# Out:
# array(['SECRETARIA MUNICIPAL MEIO AMBIENTE',
#        'SECRETARIA MUNICIPAL DA SAÚDE',
#        'SECRETARIA MUNICIPAL DE DEFESA SOCIAL E TRANSITO',
#        'SECRETARIA MUNICIPAL DA EDUCAÇÃO', 'URBANIZAÇÃO DE CURITIBA',
#        'SECRETARIA MUNICIPAL DA COMUNICAÇÃO SOCIAL',
#        'SECRETARIA MUNICIPAL DE ADMINISTRAÇÃO E DE GESTÃO DE PESSOAL',
#        'COMPANHIA DE HABITAÇÃO DE CURITIBA',
#        'SECRETARIA MUNICIPAL DE SEGURANÇA ALIMENTAR E NUTRICIONAL',
#        'FUNDAÇÃO DE AÇÃO SOCIAL', 'SECRETARIA MUNICIPAL DO URBANISMO',
#        'SECRETARIA DO GOVERNO MUNICIPAL',
#        'SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS',
#        'SECRETARIA MUNICIPAL DO ESPORTE, LAZER E JUVENTUDE',
#        'SECRETARIA MUNICIPAL DE RECURSOS HUMANOS',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA DE RELAÇÕES INTERNACIONAIS E CERIM',
#        'SECRETARIA MUNICIPAL DA CRIANCA',
#        'SECRETARIA ANTIDROGAS MUNICIPAL',
#        'SECRETARIA MUNICIPAL DE TURISMO', 'FUNDAÇÃO CULTURAL DE CURITIBA',
#        'SECRETARIA MUNICIPAL DE PLANEJAMENTO, FINANÇAS E ORÇAMENTO',
#        'SECRETARIA MUNICIPAL DO TRABALHO E EMPREGO',
#        'SECRETARIA MUNICIPAL DE SANEAMENTO', 'CURITIBA S/A',
#        'SECRETARIA EXTRAORDINARIA MUNICIPAL DE PLANEJAMENTO E COORDENAÇÃO',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA DE RELAÇÕES COM A COMUNIDADE',
#        'SECRETARIA MUNICIPAL DE TRÂNSITO',
#        'SECRETARIA MUNICIPAL DE ASSUNTOS METROPOLITANOS',
#        'SECRETARIA ESPECIAL DOS DIREITOS DA PESSOA COM DEFICIENCIA',
#        'SECRETARIA MUN. DA IND. COM. E TURISMO',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA DA COPA 2014',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA ANTIDROGAS',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA DA MULHER',
#        'SECRETARIA EXTRAORDINÁRIA MUNICIPAL DE PLANEJAMENTO E COORDENAÇÃO',
#        'INSTITUTO MUNICIPAL DE ADMINISTRAÇÃO PÚBLICA',
#        'SECRETARIA MUNICIPAL EXTRAORDINÁRIA DE RELAÇÕES INSTITUCIONAIS',
#        'SECRETARIA MUNICIPAL EXTRAORDIN&#193RIA DE POLITICA HABITACIONAL'],
#       dtype=object)

# %%
df['REGIONAL_FATO_NOME'].unique()
# Out:
# array(['PORTÃO', 'CAJURU', 'BAIRRO NOVO', 'BOA VISTA', 'MATRIZ', 'CIC',
#        'BOQUEIRÃO', 'PINHEIRINHO', 'SANTA FELICIDADE',
#        'REGIÃO METROPOLITANA', 'TATUQUARA'], dtype=object)

# %%
df['SERVICO_NOME'].unique()
# Out:
# array(['NORMAL', 'SACAF', 'GOE', 'SIGA', 'GUARDA DO CENTRO',
#        'PTC (Transporte Coletivo)', 'CICLO PATRULHA', 'SEGWAY', 'EVENTOS',
#        'SAMU', 'GPEO', 'AIFU', 'COMPDEC', 'VELADA', 'OPERAÇÃO',
#        'GTM (Motos)', 'PAZ NO FUTEBOL', 'PEDALA CURITIBA',
#        'GUARDA DE PROTEÇÃO ANIMAL', 'PATRULHA MARIA DA PENHA',
#        'GOC (Grupo Operações com Cães)', 'GPE', 'GUARDA MUNICIPAL MIRIM',
#        'PPO', 'PROJETOS ASSUNTOS COMUNITÁRIOS', 'BALADA PROTEGIDA',
#        'FISCALIZAÇÃO DE TRÂNSITO', 'SETRAN GM', 'PROTEÇÃO AMBIENTAL',
#        'GTRAN', 'TEATRO DE FANTOCHES'], dtype=object)

# %%
df['FLAG_FLAGRANTE'].unique()
# Out:
# array(['NÃO', 'SIM'], dtype=object)

# %%
df['SECRETARIA_SIGLA'].unique()
# Out:
# array(['SMMA', 'SMS', 'SMDT', 'SME', 'URBS', 'SMCS', 'SMAP', 'COHAB',
#        'SMSAN', 'FAS', 'SMU', 'SGM', 'SMOP', 'SMELJ', 'SMRH', 'SERIC',
#        'SMCR', 'SAM', 'SMTU', 'FCC', 'SMF', 'SMTE', 'SMSA', 'CSA', 'SMPC',
#        'SERCOM', 'SETRAN', 'SMAM', 'SEDPD', 'SICT', 'SECOPA', 'SEA',
#        'SMEM', 'SEPLAN', 'IMAP', 'SERIN', 'SEPHA'], dtype=object)

# %% [markdown]
# ## Salvando novo dataset

# %%
df_limpo = df

df_limpo.to_csv('../PÓS/2024-04-01_sigesguarda_-_Base_de_Dados.csv', index=False)

# %% [markdown]
# Analise de dados

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Aplicando configurações de estilo padrão (tema, escala e cores)
sns.set()

# %%
# Contagem de ocorrências por ano
ocorrencias_por_ano = df['ATENDIMENTO_ANO'].value_counts().sort_index()

# Criar gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_ano.index, y=ocorrencias_por_ano.values, color='skyblue')
plt.title('Número de Ocorrências Policiais por Ano')
plt.xlabel('Ano')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)  # Rotacionar os rótulos do eixo x para melhor visualização
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo y
plt.show()

# %%
ocorrencias_flagrante = df['FLAG_FLAGRANTE'].value_counts()
plt.figure(figsize=(6, 6))
sns.barplot(x=ocorrencias_flagrante.index, y=ocorrencias_flagrante.values, palette='Set2')
plt.title('Distribuição de Ocorrências com Flagrante')
plt.xlabel('Flagrante')
plt.ylabel('Número de Ocorrências')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(ocorrencias_flagrante, labels=ocorrencias_flagrante.index, autopct='%1.1f%%', colors=['lightblue', 'lightgreen'], startangle=140)
plt.title('Distribuição de Ocorrências com Flagrante')
plt.show()

# %%
ocorrencias_por_mes = df['OCORRENCIA_MES'].value_counts().sort_index()

# Criar gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_mes.index, y=ocorrencias_por_mes.values, color='lightblue')
plt.title('Número de Ocorrências Policiais por Mês')
plt.xlabel('Mês')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)  # Rotacionar os rótulos do eixo x para melhor visualização
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo y
plt.show()

# %%
origens_chamados = df['ORIGEM_CHAMADO_DESCRICAO'].value_counts()

# Criar gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=origens_chamados.values, y=origens_chamados.index, palette='viridis')
plt.title('Distribuição das Origens dos Chamados')
plt.xlabel('Número de Chamados')
plt.ylabel('Origem do Chamado')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
ocorrencias_por_regional = df['REGIONAL_FATO_NOME'].value_counts()

# Criar gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x=ocorrencias_por_regional.values, y=ocorrencias_por_regional.index, palette='muted')
plt.title('Número de Ocorrências Policiais por Regional')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Regional')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
# Contagem dos serviços mais frequentes
servicos_mais_frequentes = df['SERVICO_NOME'].value_counts()

# Criar gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x=servicos_mais_frequentes.values, y=servicos_mais_frequentes.index, palette='pastel')
plt.title('Serviços Mais Frequentes Realizados pela Polícia')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Serviço')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
ocorrencias_por_bairro = df['ATENDIMENTO_BAIRRO_NOME'].value_counts().head(35)  # Vamos considerar apenas os 10 primeiros bairros

# Criar gráfico de barras horizontais
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_bairro.values, y=ocorrencias_por_bairro.index, palette='rocket')
plt.title('Top 10 Bairros com Maior Número de Ocorrências')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Bairro')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
ocorrencias_por_tipo = df['NATUREZA1_DESCRICAO'].value_counts().head(30)  # Vamos considerar apenas os 10 primeiros tipos de ocorrência

# Criar gráfico de barras horizontais
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_tipo.values, y=ocorrencias_por_tipo.index, palette='mako')
plt.title('Top 10 Tipos de Ocorrência')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Tipo de Ocorrência')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_1404\1935247571.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ocorrencias_por_tipo.values, y=ocorrencias_por_tipo.index, palette='mako')

# %%
ocorrencias_por_regional_bairro = df.groupby(['REGIONAL_FATO_NOME', 'ATENDIMENTO_BAIRRO_NOME']).size().reset_index(name='ocorrencias')

# Para cada regional, identificar o bairro com mais ocorrências
bairros_mais_ocorrencias_por_regional = ocorrencias_por_regional_bairro.groupby('REGIONAL_FATO_NOME').apply(lambda x: x.nlargest(5, 'ocorrencias'))

# Criar gráficos de barras horizontais para cada regional
for regional, data in bairros_mais_ocorrencias_por_regional.groupby(level=0):
    plt.figure(figsize=(10, 6))
    sns.barplot(x='ocorrencias', y='ATENDIMENTO_BAIRRO_NOME', data=data, palette='muted')
    plt.title(f'Top 5 Bairros com Mais Ocorrências em {regional}')
    plt.xlabel('Número de Ocorrências')
    plt.ylabel('Bairro')
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
    plt.show()

# %%
# Filtrar as ocorrências relacionadas a roubo, furto ou crimes contra o patrimônio
ocorrencias_patrimonio = df[df['NATUREZA1_DESCRICAO'].str.contains('roubo|furto|patrimônio', case=False)]

# Agrupar os dados por bairro e contar o número de ocorrências de crimes contra o patrimônio em cada bairro
ocorrencias_por_bairro_patrimonio = ocorrencias_patrimonio['ATENDIMENTO_BAIRRO_NOME'].value_counts().head(10)

# Criar gráfico de barras horizontais
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_bairro_patrimonio.values, y=ocorrencias_por_bairro_patrimonio.index, palette='muted')
plt.title('Top 10 Bairros com Mais Ocorrências de Crimes contra o Patrimônio')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Bairro')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
# Supondo que você já carregou seus dados em um DataFrame chamado df

# Filtrar as ocorrências relacionadas a "apoio"
ocorrencias_apoio = df[df['NATUREZA1_DESCRICAO'].str.contains('Animais', case=False)]

# Agrupar os dados por bairro e contar o número de ocorrências de "apoio" em cada bairro
ocorrencias_por_bairro_apoio = ocorrencias_apoio['ATENDIMENTO_BAIRRO_NOME'].value_counts().head(10)

# Criar gráfico de barras horizontais
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_bairro_apoio.values, y=ocorrencias_por_bairro_apoio.index, palette='muted')
plt.title('Top 10 Bairros com Mais Ocorrências de "Animais"')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Bairro')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
df['HORA'] = pd.to_datetime(df['OCORRENCIA_HORA']).dt.hour

# Contagem das ocorrências por hora
ocorrencias_por_hora = df['HORA'].value_counts().sort_index()

# Criar gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_hora.index, y=ocorrencias_por_hora.values, color='skyblue')
plt.title('Número de Ocorrências por Hora do Dia')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)  # Rotacionar os rótulos do eixo x para facilitar a leitura
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo y
plt.show()

# %%
# Filtrar o DataFrame apenas para as ocorrências que ocorreram no centro
ocorrencias_centro = df[df['ATENDIMENTO_BAIRRO_NOME'] == 'CIDADE INDUSTRIAL']

# Verificar se há dados no DataFrame filtrado
if ocorrencias_centro.empty:
    print("Não há dados para o bairro Centro.")
else:
    # Converter a coluna 'OCORRENCIA_HORA' para o formato de data e hora
    ocorrencias_centro['OCORRENCIA_HORA'] = pd.to_datetime(ocorrencias_centro['OCORRENCIA_HORA'])

    # Extrair a hora do horário das ocorrências no centro
    ocorrencias_centro['HORA'] = ocorrencias_centro['OCORRENCIA_HORA'].dt.hour

    # Criar gráfico de distribuição das ocorrências por hora
    plt.figure(figsize=(10, 6))
    sns.histplot(data=ocorrencias_centro, x='HORA', bins=24, kde=True, color='skyblue')
    plt.title('Distribuição das Ocorrências no Centro por Hora do Dia')
    plt.xlabel('Hora do Dia')
    plt.ylabel('Número de Ocorrências')
    plt.xticks(range(24))  # Definir os ticks do eixo x para representar as horas do dia
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo y
    plt.show()
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_1404\1456392705.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocorrencias_centro['OCORRENCIA_HORA'] = pd.to_datetime(ocorrencias_centro['OCORRENCIA_HORA'])
# C:\Users\chii\AppData\Local\Temp\ipykernel_1404\1456392705.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocorrencias_centro['HORA'] = ocorrencias_centro['OCORRENCIA_HORA'].dt.hour

# %%
# Filtrar o DataFrame para incluir apenas as ocorrências que contenham a palavra "óbito" na descrição
ocorrencias_obito = df[df['NATUREZA1_DESCRICAO'].str.contains('Vadiagem', case=False)]

# Contar o número de ocorrências por bairro
ocorrencias_por_bairro = ocorrencias_obito['ATENDIMENTO_BAIRRO_NOME'].value_counts()

# Criar gráfico de barras para visualizar a distribuição das ocorrências por bairro
plt.figure(figsize=(10, 6))
sns.barplot(x=ocorrencias_por_bairro.values, y=ocorrencias_por_bairro.index, palette='viridis')
plt.title('Distribuição de Ocorrências com Palavras Contendo "Óbito" por Bairro')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Bairro')
plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
plt.show()

# %%
ocorrencias_batel = df[df['ATENDIMENTO_BAIRRO_NOME'] == 'PRADO VELHO']

# Verificar se há dados no DataFrame filtrado
if ocorrencias_batel.empty:
    print("Não há ocorrências no bairro JARDIM SOCIAL.")
else:
    # Contar o número de ocorrências por categoria ou descrição
    ocorrencias_por_categoria = ocorrencias_batel['NATUREZA1_DESCRICAO'].value_counts().head(5)

    # Criar gráfico de barras para visualizar a distribuição das ocorrências por categoria
    plt.figure(figsize=(12, 8))
    sns.barplot(y=ocorrencias_por_categoria.index, x=ocorrencias_por_categoria.values, palette='magma')
    plt.title('Top 5 ocorrências no bairro PRADO VELHO',fontsize=25)
    plt.xlabel('Número de Ocorrências')
    plt.ylabel(' ')
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=20)
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
    plt.show()

ocorrencias_batel = df[df['ATENDIMENTO_BAIRRO_NOME'] == 'CABRAL']

# Verificar se há dados no DataFrame filtrado
if ocorrencias_batel.empty:
    print("Não há ocorrências no bairro JARDIM SOCIAL.")
else:
    # Contar o número de ocorrências por categoria ou descrição
    ocorrencias_por_categoria = ocorrencias_batel['NATUREZA1_DESCRICAO'].value_counts().head(5)

    # Criar gráfico de barras para visualizar a distribuição das ocorrências por categoria
    plt.figure(figsize=(12, 8))
    sns.barplot(y=ocorrencias_por_categoria.index, x=ocorrencias_por_categoria.values, palette='magma')
    plt.title('Top 5 ocorrências no bairro CABRAL',fontsize=25)
    plt.xlabel('Número de Ocorrências')
    plt.ylabel(' ')
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=20)
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Adicionar linhas de grade no eixo x
    plt.show()
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_2948\2932038991.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=ocorrencias_por_categoria.index, x=ocorrencias_por_categoria.values, palette='magma')
# C:\Users\chii\AppData\Local\Temp\ipykernel_2948\2932038991.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=ocorrencias_por_categoria.index, x=ocorrencias_por_categoria.values, palette='magma')
